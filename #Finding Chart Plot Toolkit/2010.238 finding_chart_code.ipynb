# %%
# Code that generates a finding chart from a FITS file and mark/label stars

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib.cm as cm
import matplotlib.image as mpimg
import matplotlib.patches as patches
from astropy.utils.data import download_file
from astropy.io import fits
from pylab import *
from optparse import OptionParser
from matplotlib import gridspec
from matplotlib.colors import LogNorm
from matplotlib.patches import ConnectionPatch
from mpl_toolkits.axes_grid1 import ImageGrid
from PIL import Image
import copy

fig = plt.figure(figsize=(12, 12))

########################

image_2010_03_29 = fits.getdata('2010_03_29_mosaic.fits')
image_2010_03_29t = np.sqrt((image_2010_03_29/1.5e+5)**2) + 1e-20
plt.imshow(image_2010_03_29t, cmap='gray', norm=LogNorm(vmin=0.0002, vmax=.002), origin='lower', interpolation='none')
plt.axis('off')

plt.title('2010.238', fontsize = 25)
plt.plot(162.96-1, 152.43-1, '*', markeredgewidth=1, color='yellow', markersize=20)
plt.xlim(112.96000000000001-1, 212.96-1)
plt.ylim(102.43-1, 202.43-1)

plt.scatter(163.41-1, 155.83-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('S4711', xy=(163.41-1, 155.83-1), xytext=(163.41-1-2.5, 155.83-1+3), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(173.72-1, 153.42-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('S4712', xy=(173.72-1, 153.42-1), xytext=(173.72-1+1.5, 153.42-1+1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(160.0-1, 148.0-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('S4713', xy=(160.0-1, 148.0-1), xytext=(160.0-1-7.5, 148.0-1+-3), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(173.0-1, 165.0-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('S4714', xy=(173.0-1, 165.0-1), xytext=(173.0-1+2.5, 165.0-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(166.97-1, 150.71-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('S4715', xy=(166.97-1, 150.71-1), xytext=(166.97-1-2.5, 150.71-1+-4), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(198.15-1, 144.15-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('S43', xy=(198.15-1, 144.15-1), xytext=(198.15-1+2.5, 144.15-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(195.81-1, 132.11-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('S51', xy=(195.81-1, 132.11-1), xytext=(195.81-1+2.5, 132.11-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(173.4-1, 147.19-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('8', xy=(173.4-1, 147.19-1), xytext=(173.4-1+2.5, 147.19-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(167.06-1, 137.48-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('9', xy=(167.06-1, 137.48-1), xytext=(167.06-1+2.5, 137.48-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(173.1-1, 140.77-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('10', xy=(173.1-1, 140.77-1), xytext=(173.1-1+2.5, 140.77-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(159.85-1, 140.44-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('11', xy=(159.85-1, 140.44-1), xytext=(159.85-1+2.5, 140.44-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(156.46-1, 134.41-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('12', xy=(156.46-1, 134.41-1), xytext=(156.46-1+2.5, 134.41-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(164.7-1, 132.71-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('13', xy=(164.7-1, 132.71-1), xytext=(164.7-1+2.5, 132.71-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(122.94-1, 167.58-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('101', xy=(122.94-1, 167.58-1), xytext=(122.94-1+2.5, 167.58-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(129.58-1, 155.19-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('102', xy=(129.58-1, 155.19-1), xytext=(129.58-1-6, 155.19-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(138.46-1, 147.75-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('103', xy=(138.46-1, 147.75-1), xytext=(138.46-1+2.5, 147.75-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(135.0-1, 153.0-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('104', xy=(135.0-1, 153.0-1), xytext=(135.0-1-6, 153.0-1+-2.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(127.23-1, 141.85-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('105', xy=(127.23-1, 141.85-1), xytext=(127.23-1+2.5, 141.85-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(120.6-1, 130.21-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('106', xy=(120.6-1, 130.21-1), xytext=(120.6-1+2.5, 130.21-1+-0.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(140.05-1, 136.29-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('107', xy=(140.05-1, 136.29-1), xytext=(140.05-1-6, 136.29-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(140.88-1, 122.16-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('108', xy=(140.88-1, 122.16-1), xytext=(140.88-1+2.5, 122.16-1+-1), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(143.71-1, 118.14-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('109', xy=(143.71-1, 118.14-1), xytext=(143.71-1+2.5, 118.14-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(184.0-1, 155.0-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('111', xy=(184.0-1, 155.0-1), xytext=(184.0-1+2.5, 155.0-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(194.46-1, 158.11-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('112', xy=(194.46-1, 158.11-1), xytext=(194.46-1+2.5, 158.11-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(186.98-1, 147.85-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('113', xy=(186.98-1, 147.85-1), xytext=(186.98-1+2.5-7, 147.85-1+-3.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(192.84-1, 150.54-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('114', xy=(192.84-1, 150.54-1), xytext=(192.84-1+2.5, 150.54-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(193.14-1, 137.9-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('116', xy=(193.14-1, 137.9-1), xytext=(193.14-1+2.5, 137.9-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(141.1-1, 154.53-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('301', xy=(141.1-1, 154.53-1), xytext=(141.1-1+2.5, 154.53-1+-1.5), color='lime', fontsize=15, fontstyle='normal')
plt.scatter(145.74-1, 133.93-1, s=1500, facecolors='none', color='lime', linewidth=1, linestyle='dashed')
plt.annotate('304', xy=(145.74-1, 133.93-1), xytext=(145.74-1+2.5, 133.93-1+-1.5), color='lime', fontsize=15, fontstyle='normal')


plt.annotate('S25', xy=(170.0-1, 120.5-1), xytext=(170.0-1+0, 120.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S7', xy=(124.5-1, 147.5-1), xytext=(124.5-1+0, 147.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S59', xy=(177.0-1, 169.5-1), xytext=(177.0-1+0, 169.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S54', xy=(153.5-1, 141.0-1), xytext=(153.5-1+0, 141.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S36', xy=(139.0-1, 169.0-1), xytext=(139.0-1+0, 169.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S62', xy=(168.0-1, 156.5-1), xytext=(168.0-1+0, 156.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S18', xy=(181.0-1, 140.0-1), xytext=(181.0-1+0, 140.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S13', xy=(149.5-1, 162.5-1), xytext=(149.5-1+0, 162.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S60', xy=(181.0-1, 160.0-1), xytext=(181.0-1+0, 160.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S31', xy=(175.0-1, 159.5-1), xytext=(175.0-1+0, 159.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S61', xy=(178.0-1, 146.0-1), xytext=(178.0-1+0, 146.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S39', xy=(170.5-1, 176.5-1), xytext=(170.5-1+0, 176.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S64', xy=(168.0-1, 170.5-1), xytext=(168.0-1+0, 170.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S12', xy=(162.0-1, 183.0-1), xytext=(162.0-1+0, 183.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S33', xy=(200.5-1, 123.5-1), xytext=(200.5-1+0, 123.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S6', xy=(123.0-1, 159.5-1), xytext=(123.0-1+0, 159.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S21', xy=(189.0-1, 143.5-1), xytext=(189.0-1+0, 143.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S32', xy=(186.5-1, 125.0-1), xytext=(186.5-1+0, 125.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S44', xy=(171.0-1, 131.5-1), xytext=(171.0-1+0, 131.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S41', xy=(177.0-1, 128.0-1), xytext=(177.0-1+0, 128.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S42', xy=(175.5-1, 133.5-1), xytext=(175.5-1+0, 133.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S57', xy=(134.0-1, 140.5-1), xytext=(134.0-1+0, 140.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S23', xy=(143.5-1, 140.5-1), xytext=(143.5-1+0, 140.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('DSO', xy=(151.5-1, 147.5-1), xytext=(151.5-1+0, 147.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S63', xy=(148.5-1, 143.5-1), xytext=(148.5-1+0, 143.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S8', xy=(127.5-1, 126.5-1), xytext=(127.5-1+0, 126.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S10', xy=(159.5-1, 125.0-1), xytext=(159.5-1+0, 125.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S9', xy=(148.0-1, 124.0-1), xytext=(148.0-1+0, 124.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S22', xy=(139.0-1, 129.0-1), xytext=(139.0-1+0, 129.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S1', xy=(152.0-1, 129.0-1), xytext=(152.0-1+0, 129.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S55', xy=(162.0-1, 151.0-1), xytext=(162.0-1+0, 151.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S17', xy=(157.0-1, 154.5-1), xytext=(157.0-1+0, 154.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S38', xy=(179.5-1, 152.0-1), xytext=(179.5-1+0, 152.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S175', xy=(158.0-1, 147.5-1), xytext=(158.0-1+0, 147.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S19', xy=(164.0-1, 143.0-1), xytext=(164.0-1+0, 143.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S29', xy=(175.0-1, 181.0-1), xytext=(175.0-1+0, 181.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S40', xy=(147.0-1, 156.5-1), xytext=(147.0-1+0, 156.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S14', xy=(141.0-1, 167.0-1), xytext=(141.0-1+0, 167.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S20', xy=(146.0-1, 158.5-1), xytext=(146.0-1+0, 158.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S56', xy=(155.0-1, 162.5-1), xytext=(155.0-1+0, 162.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S4', xy=(135.5-1, 160.5-1), xytext=(135.5-1+0, 160.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S52', xy=(144.5-1, 172.5-1), xytext=(144.5-1+0, 172.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S5', xy=(137.0-1, 170.5-1), xytext=(137.0-1+0, 170.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S47', xy=(133.0-1, 172.0-1), xytext=(133.0-1+0, 172.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S37', xy=(139.0-1, 185.0-1), xytext=(139.0-1+0, 185.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S2', xy=(164.5-1, 165.0-1), xytext=(164.5-1+0, 165.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S35', xy=(119.0-1, 121.0-1), xytext=(119.0-1+0, 121.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S34', xy=(132.0-1, 119.0-1), xytext=(132.0-1+0, 119.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S46', xy=(142.0-1, 112.0-1), xytext=(142.0-1+0, 112.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S45', xy=(148.0-1, 111.0-1), xytext=(148.0-1+0, 111.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S11', xy=(143.0-1, 106.5-1), xytext=(143.0-1+0, 106.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S24', xy=(169.0-1, 117.5-1), xytext=(169.0-1+0, 117.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S27', xy=(150.0-1, 193.0-1), xytext=(150.0-1+0, 193.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S28', xy=(158.5-1, 188.0-1), xytext=(158.5-1+0, 188.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S53', xy=(136.0-1, 192.0-1), xytext=(136.0-1+0, 192.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S26', xy=(118.5-1, 185.5-1), xytext=(118.5-1+0, 185.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S30', xy=(203.0-1, 182.5-1), xytext=(203.0-1+0, 182.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S58', xy=(184.0-1, 110.5-1), xytext=(184.0-1+0, 110.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S50', xy=(199.5-1, 115.0-1), xytext=(199.5-1+0, 115.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S79', xy=(112.0-1, 113.0-1), xytext=(112.0-1+0, 113.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S48', xy=(129.0-1, 191.5-1), xytext=(129.0-1+0, 191.5-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S104', xy=(210.0-1, 188.0-1), xytext=(210.0-1+0, 188.0-1+0), color='blue', fontsize=15, fontstyle='normal')
plt.annotate('S49', xy=(111.0-1, 155.5-1), xytext=(111.0-1+0, 155.5-1+0), color='blue', fontsize=15, fontstyle='normal')

########################

plt.tight_layout()
plt.subplots_adjust(wspace=-.6, hspace =.2)#,vspace= -.1)
plt.savefig('2010.238 finding chart.png', dpi=500)#, bbox_inches='tight')
plt.show()
plt.close()
